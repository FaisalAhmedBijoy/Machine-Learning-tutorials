# %%
print('pivot table')
# Out:
# pivot table

# %%
import pandas as pd
df=pd.read_csv('pivot1.csv')
df
# Out:
#        date      city  temperature  humanidity
# 0  05-01-17  new york           65          56
# 1  05-02-17  new york           66          58
# 2  05-03-17  new york           68          60
# 3  05-01-17    mumbai           75          80
# 4  05-02-17    mumbai           78          83
# 5  05-03-17    mumbai           82          85
# 6  05-01-17   beijing           80          26
# 7  05-02-17   beijing           77          30
# 8  05-03-17   beijing           79          35

# %%
df.pivot(index='date' ,columns='city')
# Out:
#          temperature                 humanidity
# city         beijing mumbai new york    beijing mumbai new york
# date
# 05-01-17          80     75       65         26     80       56
# 05-02-17          77     78       66         30     83       58
# 05-03-17          79     82       68         35     85       60

# %%
df.pivot(index='city' ,columns='date')
# Out:
#          temperature                   humanidity
# date        05-01-17 05-02-17 05-03-17   05-01-17 05-02-17 05-03-17
# city
# beijing           80       77       79         26       30       35
# mumbai            75       78       82         80       83       85
# new york          65       66       68         56       58       60

# %%
df.pivot(index='city',columns='date',values='humanidity')
# Out:
# date      05-01-17  05-02-17  05-03-17
# city
# beijing         26        30        35
# mumbai          80        83        85
# new york        56        58        60

# %%
df.pivot(index='city',columns='date')
# Out:
#          temperature                   humanidity
# date        05-01-17 05-02-17 05-03-17   05-01-17 05-02-17 05-03-17
# city
# beijing           80       77       79         26       30       35
# mumbai            75       78       82         80       83       85
# new york          65       66       68         56       58       60

# %%
df=pd.read_csv('pivot2.csv')
df
# Out:
#        date    city  temperature  humanidity
# 0  05-01-17  london           65          56
# 1  05-01-17  london           61          54
# 2  05-02-17  london           70          60
# 3  05-02-17  london           72          62
# 4  05-01-17   paris           75          80
# 5  05-01-17   paris           78          83
# 6  05-02-17   paris           80          85
# 7  05-02-17   paris           85          84

# %%
df
# Out:
#        date    city  temperature  humanidity
# 0  05-01-17  london           65          56
# 1  05-01-17  london           61          54
# 2  05-02-17  london           70          60
# 3  05-02-17  london           72          62
# 4  05-01-17   paris           75          80
# 5  05-01-17   paris           78          83
# 6  05-02-17   paris           80          85
# 7  05-02-17   paris           85          84

# %%
df.pivot_table(index='city',columns='date')
# Out:
#        humanidity          temperature
# date     05-01-17 05-02-17    05-01-17 05-02-17
# city
# london       55.0     61.0        63.0     71.0
# paris        81.5     84.5        76.5     82.5

# %%
df.pivot_table(index='city',columns='date',aggfunc='sum')
# Out:
#        humanidity          temperature
# date     05-01-17 05-02-17    05-01-17 05-02-17
# city
# london        110      122         126      142
# paris         163      169         153      165

# %%
df.pivot_table(index='city',columns='date',aggfunc='mean')
# Out:
#        humanidity          temperature
# date     05-01-17 05-02-17    05-01-17 05-02-17
# city
# london       55.0     61.0        63.0     71.0
# paris        81.5     84.5        76.5     82.5

# %%
# %matplotlib inline
df.plot()

# %%
df.pivot_table(index='city',columns='date',margins=True)
# Out:
#        humanidity                temperature
# date     05-01-17 05-02-17   All    05-01-17 05-02-17    All
# city
# london      55.00    61.00  58.0       63.00    71.00  67.00
# paris       81.50    84.50  83.0       76.50    82.50  79.50
# All         68.25    72.75  70.5       69.75    76.75  73.25

# %%
df=pd.read_csv('pivot3.csv')
df
# Out:
#        date   city  temperature  humanidity
# 0  05-01-17  paris           65          56
# 1  05-02-17  paris           61          54
# 2  05-03-17  paris           70          60
# 3  12-01-17  paris           36          50
# 4  12-02-17  paris           26          52
# 5  12-03-17  paris           25          51

# %%
df.plot()

# %%
type(df.date[0])
# Out:
# str

# %%
df['date']=pd.to_date(df['date'])
type(df.date[0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-c3b5fac0cb96> in <module>
# ----> 1 df['date']=pd.to_date(df.date)
#       2 type(df.date[0])
#
# AttributeError: module 'pandas' has no attribute 'to_date'

# %%
df['date']=pd.to_datetime(df['date'])
type(df.date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df
# Out:
#         date   city  temperature  humanidity
# 0 2017-05-01  paris           65          56
# 1 2017-05-02  paris           61          54
# 2 2017-05-03  paris           70          60
# 3 2017-12-01  paris           36          50
# 4 2017-12-02  paris           26          52
# 5 2017-12-03  paris           25          51

# %%
df.pivot_table(index=pd.Grouper(freq='M' ,key='date'),columns='city')
# Out:
#            humanidity temperature
# city            paris       paris
# date
# 2017-05-31  56.666667   65.333333
# 2017-12-31  51.000000   29.000000

# %%
df
# Out:
#         date   city  temperature  humanidity
# 0 2017-05-01  paris           65          56
# 1 2017-05-02  paris           61          54
# 2 2017-05-03  paris           70          60
# 3 2017-12-01  paris           36          50
# 4 2017-12-02  paris           26          52
# 5 2017-12-03  paris           25          51

# %%
print('Reshape dataframe using melt')
# Out:
# Reshape dataframe using melt

# %%
df=pd.read_csv('reshapemelt.csv')
df
# Out:
#          day  chicago  chennai  berlin
# 0     Monday       32       75      41
# 1    Tuesday       30       77      43
# 2  Wednesday       28       75      45
# 3   thrusday       22       82      38
# 4     Friday       30       83      40
# 5   Saturday       25       81      45
# 6     Sunday       35       77      47

# %%
df=pd.read_csv('reshapemelt.csv')
df
# Out:
#          day  chicago  chennai  berlin
# 0     Monday       32       75      41
# 1    Tuesday       30       77      43
# 2  Wednesday       28       75      45
# 3   thrusday       22       82      38
# 4     Friday       30       83      40
# 5   Saturday       25       81      45
# 6     Sunday       35       77      47

# %%
df1=pd.melt(df,id_vars=['day'])
df1
# Out:
#           day variable  value
# 0      Monday  chicago     32
# 1     Tuesday  chicago     30
# 2   Wednesday  chicago     28
# 3    thrusday  chicago     22
# 4      Friday  chicago     30
# 5    Saturday  chicago     25
# 6      Sunday  chicago     35
# 7      Monday  chennai     75
# 8     Tuesday  chennai     77
# 9   Wednesday  chennai     75
# 10   thrusday  chennai     82
# 11     Friday  chennai     83
# 12   Saturday  chennai     81
# 13     Sunday  chennai     77
# 14     Monday   berlin     41
# 15    Tuesday   berlin     43
# 16  Wednesday   berlin     45
# 17   thrusday   berlin     38
# 18     Friday   berlin     40
# 19   Saturday   berlin     45
# 20     Sunday   berlin     47

# %%
df1=pd.melt(df,id_vars=['day'],var_name='city',value_name='temperature')
df1
# Out:
#           day     city  temperature
# 0      Monday  chicago           32
# 1     Tuesday  chicago           30
# 2   Wednesday  chicago           28
# 3    thrusday  chicago           22
# 4      Friday  chicago           30
# 5    Saturday  chicago           25
# 6      Sunday  chicago           35
# 7      Monday  chennai           75
# 8     Tuesday  chennai           77
# 9   Wednesday  chennai           75
# 10   thrusday  chennai           82
# 11     Friday  chennai           83
# 12   Saturday  chennai           81
# 13     Sunday  chennai           77
# 14     Monday   berlin           41
# 15    Tuesday   berlin           43
# 16  Wednesday   berlin           45
# 17   thrusday   berlin           38
# 18     Friday   berlin           40
# 19   Saturday   berlin           45
# 20     Sunday   berlin           47
