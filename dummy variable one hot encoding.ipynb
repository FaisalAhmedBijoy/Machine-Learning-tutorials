# %%
print('Dummy variable and one hot encoding')
# Out:
# Dummy variable and one hot encoding

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df=pd.read_csv('dummyonehotencoding.csv')
df
# Out:
#               town  area   price
# 0   monre township  2600  550000
# 1   monre township  3000  565000
# 2   monre township  3200  610000
# 3   monre township  3600  680000
# 4   monre township  4000  725000
# 5     west windsor  2600  585000
# 6     west windsor  2800  615000
# 7     west windsor  3300  615000
# 8     west windsor  3600  650000
# 9      robinsville  2600  710000
# 10     robinsville  2900  575000
# 11     robinsville  3100  600000
# 12     robinsville  3600  620000

# %%
plt.plot(df.area,df.price)

# %%
pd.get_dummies(df.town)
# Out:
#     monre township  robinsville  west windsor
# 0                1            0             0
# 1                1            0             0
# 2                1            0             0
# 3                1            0             0
# 4                1            0             0
# 5                0            0             1
# 6                0            0             1
# 7                0            0             1
# 8                0            0             1
# 9                0            1             0
# 10               0            1             0
# 11               0            1             0
# 12               0            1             0

# %%
dummies=pd.get_dummies(df.town)
dummies
# Out:
#     monre township  robinsville  west windsor
# 0                1            0             0
# 1                1            0             0
# 2                1            0             0
# 3                1            0             0
# 4                1            0             0
# 5                0            0             1
# 6                0            0             1
# 7                0            0             1
# 8                0            0             1
# 9                0            1             0
# 10               0            1             0
# 11               0            1             0
# 12               0            1             0

# %%
merged=pd.concat([df,dummies],axis='columns')
merged
# Out:
#               town  area   price  monre township  robinsville  west windsor
# 0   monre township  2600  550000               1            0             0
# 1   monre township  3000  565000               1            0             0
# 2   monre township  3200  610000               1            0             0
# 3   monre township  3600  680000               1            0             0
# 4   monre township  4000  725000               1            0             0
# 5     west windsor  2600  585000               0            0             1
# 6     west windsor  2800  615000               0            0             1
# 7     west windsor  3300  615000               0            0             1
# 8     west windsor  3600  650000               0            0             1
# 9      robinsville  2600  710000               0            1             0
# 10     robinsville  2900  575000               0            1             0
# 11     robinsville  3100  600000               0            1             0
# 12     robinsville  3600  620000               0            1             0

# %%
final=merged.drop(['town','west windsor'],axis='columns')
final
# Out:
#     area   price  monre township  robinsville
# 0   2600  550000               1            0
# 1   3000  565000               1            0
# 2   3200  610000               1            0
# 3   3600  680000               1            0
# 4   4000  725000               1            0
# 5   2600  585000               0            0
# 6   2800  615000               0            0
# 7   3300  615000               0            0
# 8   3600  650000               0            0
# 9   2600  710000               0            1
# 10  2900  575000               0            1
# 11  3100  600000               0            1
# 12  3600  620000               0            1

# %%
x=final.drop(['price'],axis='columns')
x
# Out:
#     area  monre township  robinsville
# 0   2600               1            0
# 1   3000               1            0
# 2   3200               1            0
# 3   3600               1            0
# 4   4000               1            0
# 5   2600               0            0
# 6   2800               0            0
# 7   3300               0            0
# 8   3600               0            0
# 9   2600               0            1
# 10  2900               0            1
# 11  3100               0            1
# 12  3600               0            1

# %%
y=final.price
y
# Out:
# 0     550000
# 1     565000
# 2     610000
# 3     680000
# 4     725000
# 5     585000
# 6     615000
# 7     615000
# 8     650000
# 9     710000
# 10    575000
# 11    600000
# 12    620000
# Name: price, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x,y)
plt.plot(x,y)
# Out:
# [<matplotlib.lines.Line2D at 0x2725a070d68>,
#  <matplotlib.lines.Line2D at 0x2725a070e80>,
#  <matplotlib.lines.Line2D at 0x2725a070fd0>]

# %%
model.predict([[2800,0,1]])
# Out:
# array([609428.34874221])

# %%
model.score(x,y)
# Out:
# 0.30652959884112385

# %%
model.score(x,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7ad9b281eeba> in <module>
# ----> 1 model.score(x,y)
#
# NameError: name 'model' is not defined
