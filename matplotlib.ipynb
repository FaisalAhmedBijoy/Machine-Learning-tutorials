# %%
print('matplotlib')
# Out:
# matplotlib

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

x=[1,2,3,4,5,6,7]
y=[50,51,52,48,47,49,46]
plt.plot(x,y)

# %%
plt.plot(x,y,color='green',linewidth=5,linestyle='dotted')

# %%
plt.xlabel('Day')
plt.ylabel('temeprature')
plt.title('weather')
# Out:
# Text(0.5, 1.0, 'weather')

# %%
plt.xlabel('Day')
plt.ylabel('temeprature')
plt.title('weather')
plt.plot(x,y,'g*--')

# %%
plt.plot(x,y,color='red',marker='D',linestyle='--')

# %%
plt.plot(x,y,color='#FF5566',marker='+',markersize=10)

# %%
plt.plot(x,y,alpha=.8)

# %%
print('Axes lable,label,legend ,grid')
# Out:
# Axes lable,label,legend ,grid

# %%
days=[1,2,3,4,5,6,7]
max_t=[50,51,52,48,47,49,46]
min_t=[43,42,41,44,33,35,37]
avg_t=[45,48,48,46,40,42,41]

plt.xlabel('Days')
plt.ylabel('Temperature')
plt.title('weather')

plt.plot(days,max_t)
plt.plot(days,min_t)
plt.plot(days,avg_t)

# %%
days=[1,2,3,4,5,6,7]
max_t=[50,51,52,48,47,49,46]
min_t=[43,42,41,44,33,35,37]
avg_t=[45,48,48,46,40,42,41]

plt.xlabel('Days')
plt.ylabel('Temperature')
plt.title('weather')

plt.plot(days,max_t,label='max')
plt.plot(days,min_t,label='min')
plt.plot(days,avg_t,label='avg')
plt.legend(loc='best',shadow=True,fontsize='small')
plt.grid()

# %%
print('Bar chart')
# Out:
# Bar chart

# %%
import numpy as np
company=['Google','Amazon','Microsoft','Facebook']
revenue=[90,136,89,27]
profit=[40,10,34,20]

plt.xlabel('Company')
plt.ylabel('Revenue USD ')
plt.title('US Tech Company')
plt.bar(company,revenue)
plt.bar(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %%
import numpy as np
company=['Google','Amazon','Microsoft','Facebook']
revenue=[90,136,89,27]
profit=[40,10,34,20]

plt.xlabel('Company')
plt.ylabel('Revenue USD ')
plt.title('US Tech Company')
xpos=np.arange(len(company))
plt.xticks(xpos,company)
plt.bar(xpos-.2,revenue,width=.4, label='Revenue')
plt.bar(xpos+.2,profit,width=.4, label='profit')
plt.legend()
