# %%
print('Time series : date_range() ')
# Out:
# Time series : date_range()

# %%
import pandas as pd
df=pd.read_csv('appledatechange.csv')
df
# Out:
#           date   close      volume    open      high       low
# 0   2019/08/23  202.64  46882840.0  209.43  212.0510  201.0000
# 1   2019/08/22  212.46  22267820.0  213.19  214.4350  210.7500
# 2   2019/08/21  212.64  21564750.0  212.99  213.6500  211.6032
# 3   2019/08/20  210.36  26919530.0  210.88  213.3500  210.3200
# 4   2019/08/19  210.35  24431920.0  210.62  212.7307  210.0250
# 5   2019/08/16  206.50  28813620.0  204.28  207.1600  203.8400
# 6   2019/08/15  201.74  27883360.0  203.46  205.1400  199.6700
# 7   2019/08/14  202.75  36547440.0  203.16  206.4400  202.5869
# 8   2019/08/13  208.97  47539790.0  201.02  212.1400  200.8300
# 9   2019/08/12  200.48  22481890.0  199.62  202.0516  199.1500
# 10  2019/08/09  200.99  24619750.0  201.30  202.7600  199.2900
# 11  2019/08/08  203.43  27009520.0  200.20  203.5300  199.3900
# 12  2019/08/07  199.04  33364400.0  195.41  199.5600  193.8200
# 13  2019/08/06  197.00  35824790.0  196.31  198.0670  194.0400
# ...

# %%
df=pd.read_csv('appledatechange.csv')
df
# Out:
#      close    volume    open      high       low
# 0   202.64  46882840  209.43  212.0510  201.0000
# 1   212.46  22267820  213.19  214.4350  210.7500
# 2   212.64  21564750  212.99  213.6500  211.6032
# 3   210.36  26919530  210.88  213.3500  210.3200
# 4   210.35  24431920  210.62  212.7307  210.0250
# 5   206.50  28813620  204.28  207.1600  203.8400
# 6   201.74  27883360  203.46  205.1400  199.6700
# 7   202.75  36547440  203.16  206.4400  202.5869
# 8   208.97  47539790  201.02  212.1400  200.8300
# 9   200.48  22481890  199.62  202.0516  199.1500
# 10  200.99  24619750  201.30  202.7600  199.2900
# 11  203.43  27009520  200.20  203.5300  199.3900
# 12  199.04  33364400  195.41  199.5600  193.8200
# 13  197.00  35824790  196.31  198.0670  194.0400
# 14  193.34  52392970  197.99  198.6490  192.5800
# 15  204.02  40862120  205.53  206.4300  201.6300
# 16  208.43  54017920  213.90  218.0300  206.7435
# 17  213.04  69281360  216.42  221.3700  211.3000
# ...

# %%
rng=pd.date_range(start='6/1/19',end='6/30/17')
rng
# Out:
# DatetimeIndex([], dtype='datetime64[ns]', freq='D')

# %%
rng=pd.date_range(start='6/1/19',end='6/30/17',freq='B')
rng
# Out:
# DatetimeIndex([], dtype='datetime64[ns]', freq='B')

# %%
# %matplotlib inline
df.plot()

# %%
df
rng
# df.set_index(rng,inplace=True)
# Out:
# DatetimeIndex([], dtype='datetime64[ns]', freq='B')

# %%
rng
# Out:
# DatetimeIndex([], dtype='datetime64[ns]', freq='B')

# %%
df
# Out:
# Out:
#         date   close    volume    open      high       low
# 0   23-08-19  202.64  46882840  209.43  212.0510  201.0000
# 1   22-08-19  212.46  22267820  213.19  214.4350  210.7500
# 2   21-08-19  212.64  21564750  212.99  213.6500  211.6032
# 3   20-08-19  210.36  26919530  210.88  213.3500  210.3200
# 4   19-08-19  210.35  24431920  210.62  212.7307  210.0250
# 5   16-08-19  206.50  28813620  204.28  207.1600  203.8400
# 6   15-08-19  201.74  27883360  203.46  205.1400  199.6700
# 7   14-08-19  202.75  36547440  203.16  206.4400  202.5869
# 8   13-08-19  208.97  47539790  201.02  212.1400  200.8300
# 9   12-08-19  200.48  22481890  199.62  202.0516  199.1500
# 10  09-08-19  200.99  24619750  201.30  202.7600  199.2900
# 11  08-08-19  203.43  27009520  200.20  203.5300  199.3900
# 12  07-08-19  199.04  33364400  195.41  199.5600  193.8200
# 13  06-08-19  197.00  35824790  196.31  198.0670  194.0400
# 14  05-08-19  193.34  52392970  197.99  198.6490  192.5800
# ...

# %%
df['date']=pd.to_datetime(df['date'])
type(df.date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df
# Out:
#          date   close    volume    open      high       low
# 0  2019-08-23  202.64  46882840  209.43  212.0510  201.0000
# 1  2019-08-22  212.46  22267820  213.19  214.4350  210.7500
# 2  2019-08-21  212.64  21564750  212.99  213.6500  211.6032
# 3  2019-08-20  210.36  26919530  210.88  213.3500  210.3200
# 4  2019-08-19  210.35  24431920  210.62  212.7307  210.0250
# 5  2019-08-16  206.50  28813620  204.28  207.1600  203.8400
# 6  2019-08-15  201.74  27883360  203.46  205.1400  199.6700
# 7  2019-08-14  202.75  36547440  203.16  206.4400  202.5869
# 8  2019-08-13  208.97  47539790  201.02  212.1400  200.8300
# 9  2019-12-08  200.48  22481890  199.62  202.0516  199.1500
# 10 2019-09-08  200.99  24619750  201.30  202.7600  199.2900
# 11 2019-08-08  203.43  27009520  200.20  203.5300  199.3900
# 12 2019-07-08  199.04  33364400  195.41  199.5600  193.8200
# 13 2019-06-08  197.00  35824790  196.31  198.0670  194.0400
# 14 2019-05-08  193.34  52392970  197.99  198.6490  192.5800
# ...

# %%
df.asfreq('D',method='pad')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-6a802820b371> in <module>
# ----> 1 df.asfreq('D',method='pad')
#
# D:\Anaconda\lib\site-packages\pandas\core\generic.py in asfreq(self, freq, method, how, normalize, fill_value)
#    7729         from pandas.core.resample import asfreq
#    7730         return asfreq(self, freq, method=method, how=how, normalize=normalize,
# -> 7731                       fill_value=fill_value)
#    7732
#    7733     def at_time(self, time, asof=False, axis=None):
#
# D:\Anaconda\lib\site-packages\pandas\core\resample.py in asfreq(obj, freq, method, how, normalize, fill_value)
#    1760         dti = date_range(obj.index[0], obj.index[-1], freq=freq)
#    1761         dti.name = obj.index.name
# -> 1762         new_obj = obj.reindex(dti, method=method, fill_value=fill_value)
#    1763         if normalize:
# ...
