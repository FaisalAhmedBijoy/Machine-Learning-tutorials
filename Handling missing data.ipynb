# %%
print('Missing Data : fillna ,dropna,interpolate')
# Out:
# Missing Data : fillna ,dropna,interpolate

# %%
import pandas as pd
df=pd.read_csv('newyork.csv')
df
# Out:
#         day  temperature  windspeed   event
# 0  01-01-17         32.0        6.0    rain
# 1  01-04-17          NaN        9.0   sunny
# 2  01-05-17         28.0        NaN    snow
# 3  01-06-17          NaN        7.0     NaN
# 4  01-07-17         32.0        NaN    rain
# 5  01-08-17          NaN        NaN   sunny
# 6  01-09-17          NaN        NaN     NaN
# 7  01-10-17         34.0        8.0  cloudy
# 8  01-11-17         40.0       12.0   sunny

# %%
type(df.day[0])
# Out:
# str

# %%
df.day[0]
# Out:
# '01-01-17'

# %%
df=pd.read_csv('newyork.csv',parse_dates=['day'])
df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    rain
# 1 2017-01-04          NaN        9.0   sunny
# 2 2017-01-05         28.0        NaN    snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    rain
# 5 2017-01-08          NaN        NaN   sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  cloudy
# 8 2017-01-11         40.0       12.0   sunny

# %%
type(df.day[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df.set_index('day')
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    rain
# 2017-01-04          NaN        9.0   sunny
# 2017-01-05         28.0        NaN    snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    rain
# 2017-01-08          NaN        NaN   sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  cloudy
# 2017-01-11         40.0       12.0   sunny

# %%
df.set_index('day',inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'day'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-e53bd8c9b0f1> in <module>
# ----> 1 df.set_index('day',inplace=True)
#       2 df
#
# ...

# %%
df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    rain
# 2017-01-04          NaN        9.0   sunny
# 2017-01-05         28.0        NaN    snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    rain
# 2017-01-08          NaN        NaN   sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  cloudy
# 2017-01-11         40.0       12.0   sunny

# %%
print('fillna(0) for NaN values')
# Out:
# fillna(0) for NaN values

# %%
new_df=df.fillna(0)
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    rain
# 2017-01-04          0.0        9.0   sunny
# 2017-01-05         28.0        0.0    snow
# 2017-01-06          0.0        7.0       0
# 2017-01-07         32.0        0.0    rain
# 2017-01-08          0.0        0.0   sunny
# 2017-01-09          0.0        0.0       0
# 2017-01-10         34.0        8.0  cloudy
# 2017-01-11         40.0       12.0   sunny

# %%
new_df=df.fillna({
    
    'temperature':0,
    'windspeed':0,
    'event':'no event'
})
new_df
# Out:
#             temperature  windspeed     event
# day
# 2017-01-01         32.0        6.0      rain
# 2017-01-04          0.0        9.0     sunny
# 2017-01-05         28.0        0.0      snow
# 2017-01-06          0.0        7.0  no event
# 2017-01-07         32.0        0.0      rain
# 2017-01-08          0.0        0.0     sunny
# 2017-01-09          0.0        0.0  no event
# 2017-01-10         34.0        8.0    cloudy
# 2017-01-11         40.0       12.0     sunny

# %%
new_df=df.fillna(method='ffill')
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    rain
# 2017-01-04         32.0        9.0   sunny
# 2017-01-05         28.0        9.0    snow
# 2017-01-06         28.0        7.0    snow
# 2017-01-07         32.0        7.0    rain
# 2017-01-08         32.0        7.0   sunny
# 2017-01-09         32.0        7.0   sunny
# 2017-01-10         34.0        8.0  cloudy
# 2017-01-11         40.0       12.0   sunny

# %%
new_df=df.fillna(method='bfill')
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    rain
# 2017-01-04         28.0        9.0   sunny
# 2017-01-05         28.0        7.0    snow
# 2017-01-06         32.0        7.0    rain
# 2017-01-07         32.0        8.0    rain
# 2017-01-08         34.0        8.0   sunny
# 2017-01-09         34.0        8.0  cloudy
# 2017-01-10         34.0        8.0  cloudy
# 2017-01-11         40.0       12.0   sunny

# %%
new_df=df.fillna(method='bfill',axis='columns')
new_df
# Out:
#            temperature windspeed   event
# day
# 2017-01-01          32         6    rain
# 2017-01-04           9         9   sunny
# 2017-01-05          28      snow    snow
# 2017-01-06           7         7     NaN
# 2017-01-07          32      rain    rain
# 2017-01-08       sunny     sunny   sunny
# 2017-01-09         NaN       NaN     NaN
# 2017-01-10          34         8  cloudy
# 2017-01-11          40        12   sunny

# %%
df
new_df
# Out:
#            temperature windspeed   event
# day
# 2017-01-01          32         6    rain
# 2017-01-04           9         9   sunny
# 2017-01-05          28      snow    snow
# 2017-01-06           7         7     NaN
# 2017-01-07          32      rain    rain
# 2017-01-08       sunny     sunny   sunny
# 2017-01-09         NaN       NaN     NaN
# 2017-01-10          34         8  cloudy
# 2017-01-11          40        12   sunny

# %%
new_df=df.interpolate()
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01    32.000000       6.00    rain
# 2017-01-04    30.000000       9.00   sunny
# 2017-01-05    28.000000       8.00    snow
# 2017-01-06    30.000000       7.00     NaN
# 2017-01-07    32.000000       7.25    rain
# 2017-01-08    32.666667       7.50   sunny
# 2017-01-09    33.333333       7.75     NaN
# 2017-01-10    34.000000       8.00  cloudy
# 2017-01-11    40.000000      12.00   sunny

# %%
new_df=df.interpolate('time')
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01    32.000000       6.00    rain
# 2017-01-04    29.000000       9.00   sunny
# 2017-01-05    28.000000       8.00    snow
# 2017-01-06    30.000000       7.00     NaN
# 2017-01-07    32.000000       7.25    rain
# 2017-01-08    32.666667       7.50   sunny
# 2017-01-09    33.333333       7.75     NaN
# 2017-01-10    34.000000       8.00  cloudy
# 2017-01-11    40.000000      12.00   sunny

# %%
print('dropna : for none value remove')
# Out:
# dropna : for none value remove

# %%
new_df=df.dropna()
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    rain
# 2017-01-10         34.0        8.0  cloudy
# 2017-01-11         40.0       12.0   sunny

# %%
new_df=df.dropna(how='all')
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    rain
# 2017-01-04          NaN        9.0   sunny
# 2017-01-05         28.0        NaN    snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    rain
# 2017-01-08          NaN        NaN   sunny
# 2017-01-10         34.0        8.0  cloudy
# 2017-01-11         40.0       12.0   sunny

# %%
num_df=df.dropna(thresh=1)
num_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    rain
# 2017-01-04          NaN        9.0   sunny
# 2017-01-05         28.0        NaN    snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    rain
# 2017-01-08          NaN        NaN   sunny
# 2017-01-10         34.0        8.0  cloudy
# 2017-01-11         40.0       12.0   sunny

# %%
num_df=df.dropna(thresh=2)
num_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    rain
# 2017-01-04          NaN        9.0   sunny
# 2017-01-05         28.0        NaN    snow
# 2017-01-07         32.0        NaN    rain
# 2017-01-10         34.0        8.0  cloudy
# 2017-01-11         40.0       12.0   sunny

# %%
dt=pd.date_range('01-01-2017','01-11-2017')
idx=pd.DatetimeIndex(dt)
df=df.reindex(idx)
df
# Out:
#             temperature  windspeed   event
# 2017-01-01         32.0        6.0    rain
# 2017-01-02          NaN        NaN     NaN
# 2017-01-03          NaN        NaN     NaN
# 2017-01-04          NaN        9.0   sunny
# 2017-01-05         28.0        NaN    snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    rain
# 2017-01-08          NaN        NaN   sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  cloudy
# 2017-01-11         40.0       12.0   sunny

# %%
new_df=df.interpolate()
new_df
# Out:
#             temperature  windspeed   event
# 2017-01-01    32.000000       6.00    rain
# 2017-01-02    31.000000       7.00     NaN
# 2017-01-03    30.000000       8.00     NaN
# 2017-01-04    29.000000       9.00   sunny
# 2017-01-05    28.000000       8.00    snow
# 2017-01-06    30.000000       7.00     NaN
# 2017-01-07    32.000000       7.25    rain
# 2017-01-08    32.666667       7.50   sunny
# 2017-01-09    33.333333       7.75     NaN
# 2017-01-10    34.000000       8.00  cloudy
# 2017-01-11    40.000000      12.00   sunny

# %%
print('replace Function')
# Out:
# replace Function

# %%
import numpy as np
df=pd.read_csv('paris.csv')
df
# Out:
#         day  temperature  windspeed     event
# 0  01-01-17           32          6      rain
# 1  01-02-17         9999          6     sunny
# 2  01-03-17           28       9999  no event
# 3  01-04-17         9999          7      snow
# 4  01-05-17           32       9999  no event
# 5  01-06-17           34          6      rain

# %%
new_df=df.replace(9999,np.NaN)
new_df
# Out:
#         day  temperature  windspeed     event
# 0  01-01-17         32.0        6.0      rain
# 1  01-02-17          NaN        6.0     sunny
# 2  01-03-17         28.0        NaN  no event
# 3  01-04-17          NaN        7.0      snow
# 4  01-05-17         32.0        NaN  no event
# 5  01-06-17         34.0        6.0      rain

# %%
new_df=df.replace({
    'temperature':9999 ,
    'windspeed':9999,
    'event':'no event'
},np.NaN)
new_df
# Out:
#         day  temperature  windspeed  event
# 0  01-01-17         32.0        6.0   rain
# 1  01-02-17          NaN        6.0  sunny
# 2  01-03-17         28.0        NaN    NaN
# 3  01-04-17          NaN        7.0   snow
# 4  01-05-17         32.0        NaN    NaN
# 5  01-06-17         34.0        6.0   rain

# %%
df=pd.read_csv('paris.csv')
df
# Out:
#         day temperature windspeed     event
# 0  01-01-17         32F         6      rain
# 1  01-02-17        9999      6mph     sunny
# 2  01-03-17          28      9999  no event
# 3  01-04-17        9999      7mph      snow
# 4  01-05-17         32F      9999  no event
# 5  01-06-17          34         6      rain

# %%
new_df=df.replace('[A-Za-z]','',regex=True)
new_df
# Out:
#         day temperature windspeed event
# 0  01-01-17          32         6
# 1  01-02-17        9999         6
# 2  01-03-17          28      9999
# 3  01-04-17        9999         7
# 4  01-05-17          32      9999
# 5  01-06-17          34         6

# %%
new_df=df.replace({
    
    'temperature':'[A-Za-z]',
    'windspeed':'[A-Za-z]'
    
},'',regex=True)

new_df
# Out:
#         day temperature windspeed     event
# 0  01-01-17          32         6      rain
# 1  01-02-17        9999         6     sunny
# 2  01-03-17          28      9999  no event
# 3  01-04-17        9999         7      snow
# 4  01-05-17          32      9999  no event
# 5  01-06-17          34         6      rain

# %%
df=pd.DataFrame({
    'score':['good','poor','average','exceptional'],
    'student':['jack','mike','edward','david']
    
    
})
df
# Out:
#          score student
# 0         good    jack
# 1         poor    mike
# 2      average  edward
# 3  exceptional   david

# %%
new_df=df.replace(['poor','average','good','exceptional'],[1,2,3,4])
new_df
# Out:
#    score student
# 0      3    jack
# 1      1    mike
# 2      2  edward
# 3      4   david
